# %%
# -*- coding: utf-8 -*-

# %%
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

#主函數
if __name__ =="__main__":
  if len(sys.argv)>1:
    image = cv2.imread('/content/drive/My Drive/107-2Multimedia/559.jpg', cv2.IMREAD_GRAYSCALE)
  else:
    print("Usge:python imgToArray.py imageFile")
  plt.imshow(image,cmap='gray')
  plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image2 = cv2.imread('/content/drive/My Drive/107-2Multimedia/559.jpg', cv2.IMREAD_COLOR)#default
# plt.imshow(image2)
plt.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image3 = cv2.imread('/content/drive/My Drive/107-2Multimedia/559.jpg', cv2.IMREAD_UNCHANGED)#including alpha channel
plt.imshow(cv2.cvtColor(image3,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image4 = cv2.imread('/content/drive/My Drive/107-2Multimedia/559.jpg', 0)# -1 0 1 2 3 4....................
plt.imshow(image4)
plt.title('invert')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image5 = cv2.imread('/content/drive/My Drive/107-2Multimedia/559.jpg')
gray = cv2.cvtColor(image5, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[167, 165, 165, ..., 185, 185, 184],
#        [167, 166, 166, ..., 185, 184, 184],
#        [167, 167, 167, ..., 186, 185, 185],
#        ...,
#        [126, 123, 122, ...,  44,  54,  53],
#        [126, 121, 115, ...,  42,  44,  40],
#        [126, 118, 115, ...,  46,  52,  48]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')
plt.title('gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image6 = cv2.imread('/content/drive/My Drive/107-2Multimedia/559.jpg')
b,g,r = cv2.split(image6)#slow
img = cv2.merge((r,g,b))#slow
plt.imshow(img)
plt.title('color')
plt.xticks([])
plt.yticks([])
plt.show()
